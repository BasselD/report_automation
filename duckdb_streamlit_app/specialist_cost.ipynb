# %% [markdown]
# `pip install streamlit duckdb plotly pandas pyarrow`
#
# or
# `pip install -r requirements.txt`

# %%
import pyarrow.csv as pv
import pyarrow.parquet as pq

# Read CSV directly into a PyArrow Table
table = pv.read_csv('/Users/bassel_instructor/Documents/datasets/medicare_synthetic_12k.csv')

# Write to Parquet
pq.write_table(table, '/Users/bassel_instructor/Documents/datasets/medicare_synthetic_12k.parquet')

# %%
pip install watchdog
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
